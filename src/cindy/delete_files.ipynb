# %%
import os

directory_a = "/Users/chenhsiyu/Desktop/annotations/manual_cleaned_data/cindycleandata"
directory_b = "/Users/chenhsiyu/Desktop/annotations/meta_cleaned_data _deleted"

files_in_a = set(os.listdir(directory_a))
files_in_b = os.listdir(directory_b)

# Loop through files in B directory
for filename_b in files_in_b:
    if filename_b not in files_in_a:
        file_path_b = os.path.join(directory_b, filename_b)
        os.remove(file_path_b)
        print(f"Deleted file: {filename_b}")
# Out:
# Deleted file: 18376380.csv
# Deleted file: 16969874.csv
# Deleted file: 11047388.csv
# Deleted file: 19765544.csv
# Deleted file: 19825545.csv
# Deleted file: 17947678.csv
# Deleted file: 14089039.csv
# Deleted file: 12761450.csv
# Deleted file: 11818780.csv
# Deleted file: 12728736.csv
# Deleted file: 13163335.csv
# Deleted file: 13362087.csv
# Deleted file: 15213282.csv
# Deleted file: 12863662.csv
# Deleted file: 14997479.csv
# Deleted file: 19230956.csv
# Deleted file: 15746048.csv
# Deleted file: 15643642.csv
# Deleted file: 12961707.csv
# Deleted file: 19402201.csv
# Deleted file: 17435101.csv
# Deleted file: 19955908.csv
# Deleted file: 10064678.csv
# Deleted file: 11185977.csv
# Deleted file: 17827826.csv
# Deleted file: 14519811.csv
# Deleted file: 12127138.csv
# Deleted file: 12097837.csv
# Deleted file: 10627268.csv
# Deleted file: 13244732.csv
# Deleted file: 18509069.csv
# Deleted file: 16434888.csv
# Deleted file: 10823359.csv
# Deleted file: 18595526.csv
# ...
